# %%
import os
# define the name of the directory to be created
path = "../Modelo Final"
   
ruta_modelo = path + "/LDA-Model"

# %%
ruta_modelo
# Out:
# '../Modelo Final/LDA-Model'

# %%
from pycaret.nlp import *

lda_final = load_model(ruta_modelo)
num_topics = len(lda_final.get_topics())

import pandas as pd
import pickle


train_data_dir = path + "/train_data_.sav"
train_tokenized_words_dir = path + "/train_tokenized_words.sav"
train_corpus_dir = path + "/train_corpus.sav"
train_id2word_dir = path + "/train_id2word.sav"


test_data_dir = path + "/test/test_data_.sav"
test_tokenized_words_dir = path + "/test/test_tokenized_words.sav"
test_corpus_dir = path + "/test/test_corpus.sav"
test_id2word_dir = path + "/test/test_id2word.sav"


lda_train_results_dir = path + "/lda_train_results.df"
lda_test_results_dir = path + "/test/lda_test_results.df"


train_data_ = pickle.load(open(train_data_dir, 'rb'))
train_tokenized_words = pickle.load(open(train_tokenized_words_dir, 'rb'))                                
train_corpus = pickle.load(open(train_corpus_dir, 'rb'))
train_id2word = pickle.load(open(train_id2word_dir, 'rb')) #Diccionario gensin

test_data_ = pickle.load(open(test_data_dir, 'rb'))
test_tokenized_words = pickle.load(open(test_tokenized_words_dir, 'rb'))                                
test_corpus = pickle.load(open(test_corpus_dir, 'rb'))
test_id2word = pickle.load(open(test_id2word_dir, 'rb')) #Diccionario gensin

lda_train_results = pickle.load(open(lda_train_results_dir, 'rb'))
lda_test_results = pickle.load(open(lda_test_results_dir, 'rb'))



document_topic_matrix_dir = path + "/document_topic_matrix.sav"
topic_word_matrix_dir = path + "/topic_word_matrix.sav"

document_topic_matrix = pickle.load(open(document_topic_matrix_dir, 'rb'))
topic_word_matrix = pickle.load(open(topic_word_matrix_dir, 'rb'))
# Out:
# Model Sucessfully Loaded

# %%
document_topic_matrix
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.000052  0.000052  0.999429  0.000052  0.000052  0.000052  0.000052
# 1    0.000034  0.000034  0.000034  0.000034  0.000034  0.000034  0.763231
# 2    0.586696  0.000065  0.267503  0.000065  0.000065  0.000065  0.007368
# 3    0.000056  0.000056  0.140542  0.000056  0.000056  0.243990  0.489561
# 4    0.000033  0.000033  0.000033  0.000033  0.000033  0.000033  0.186601
# ..        ...       ...       ...       ...       ...       ...       ...
# 964  0.000046  0.000046  0.000046  0.000046  0.000046  0.999491  0.000046
# 965  0.000156  0.000156  0.000156  0.087539  0.000156  0.000156  0.000156
# 966  0.000297  0.000297  0.000297  0.000297  0.000297  0.000297  0.000297
# 967  0.000080  0.000080  0.032414  0.000080  0.000080  0.000080  0.000080
# 968  0.000034  0.000034  0.000034  0.000034  0.000034  0.000034  0.000034
#
#            7         8         9         10        11
# 0    0.000052  0.000052  0.000052  0.000052  0.000052
# 1    0.000034  0.000034  0.009632  0.000034  0.226834
# 2    0.000065  0.021325  0.011862  0.104859  0.000065
# 3    0.125460  0.000056  0.000056  0.000056  0.000056
# 4    0.000033  0.000033  0.671559  0.000033  0.141546
# ..        ...       ...       ...       ...       ...
# 964  0.000046  0.000046  0.000046  0.000046  0.000046
# 965  0.588401  0.000156  0.158603  0.114570  0.049796
# 966  0.000297  0.655663  0.202443  0.000297  0.139224
# 967  0.000080  0.966790  0.000080  0.000080  0.000080
# 968  0.649978  0.000034  0.349508  0.000034  0.000212
#
# [969 rows x 12 columns]

# %%
topic_word_matrix
# Out:
#      absence    accord   account    action        actuel       add  addition  \
# 0   0.000125  0.000998  0.000251  0.000149  1.341699e-06  0.000146  0.000848
# 1   0.000160  0.001479  0.000526  0.001096  8.503257e-06  0.000664  0.001605
# 2   0.000266  0.001619  0.000195  0.000252  1.005170e-05  0.000724  0.001552
# 3   0.000118  0.001067  0.000515  0.001280  3.843566e-07  0.000854  0.001339
# 4   0.000106  0.001951  0.000125  0.002508  6.237491e-07  0.001226  0.000831
# 5   0.000833  0.000447  0.000167  0.001479  3.664223e-07  0.000775  0.002185
# 6   0.000351  0.001798  0.000224  0.000327  5.501904e-07  0.000720  0.002239
# 7   0.000248  0.001776  0.000302  0.000074  6.866984e-07  0.001772  0.001425
# 8   0.000152  0.002685  0.000119  0.000512  8.540798e-07  0.001205  0.001106
# 9   0.000186  0.001435  0.000609  0.000097  3.362006e-07  0.000213  0.000998
# 10  0.000394  0.001472  0.000232  0.000897  7.421854e-07  0.000863  0.001353
# 11  0.000247  0.000870  0.000459  0.001206  6.917529e-07  0.000222  0.000785
#
#     additional    adjust   advance  ...      polycool   polyscience  \
# 0     0.000399  0.000433  0.000459  ...  1.327991e-06  1.328055e-06
# 1     0.000456  0.000040  0.000369  ...  6.552632e-07  6.546129e-07
# 2     0.000614  0.000326  0.000470  ...  5.383830e-07  5.394604e-07
# 3     0.000573  0.000277  0.000275  ...  3.406203e-07  3.411266e-07
# 4     0.000764  0.000089  0.000343  ...  3.378992e-07  3.383300e-07
# 5     0.000503  0.000212  0.000163  ...  3.610217e-07  3.609252e-07
# 6     0.000784  0.000306  0.000362  ...  5.532211e-07  5.526716e-07
# 7     0.000288  0.000432  0.000313  ...  8.133309e-06  8.093031e-06
# 8     0.000373  0.000227  0.000164  ...  8.345337e-07  8.351690e-07
# 9     0.000452  0.000123  0.000297  ...  3.338937e-07  3.340275e-07
# 10    0.000254  0.000347  0.000296  ...  7.185487e-07  7.189938e-07
# 11    0.000426  0.000058  0.000260  ...  6.915518e-07  6.898513e-07
#
#     resist_freeze  science_frontiersin_october        storey        tanino  \
# 0    1.328315e-06                 1.332682e-06  1.328355e-06  1.327479e-06
# 1    6.549204e-07                 6.584153e-07  6.549125e-07  6.549101e-07
# 2    5.382536e-07                 5.416799e-07  5.382045e-07  5.388094e-07
# 3    3.406215e-07                 3.425930e-07  3.408497e-07  3.407749e-07
# 4    3.380781e-07                 3.393484e-07  3.381149e-07  3.382294e-07
# 5    3.612841e-07                 3.628244e-07  3.612454e-07  3.611026e-07
# 6    5.531224e-07                 5.576883e-07  5.535620e-07  5.555406e-07
# 7    8.080457e-06                 1.627329e-05  8.153796e-06  6.906947e-06
# 8    8.354777e-07                 8.426246e-07  8.349233e-07  8.344882e-07
# 9    3.350732e-07                 3.356321e-07  3.336450e-07  3.352818e-07
# 10   7.189554e-07                 7.216815e-07  7.173998e-07  7.195874e-07
# 11   6.897395e-07                 6.932574e-07  6.902577e-07  6.906334e-07
#
#      uninstalled   vernon_hill  warmed_plant   waterlogged
# 0   1.327598e-06  1.327880e-06  1.335646e-06  1.326649e-06
# 1   6.551493e-07  6.551658e-07  6.615308e-07  6.550292e-07
# 2   5.385317e-07  5.387837e-07  5.488264e-07  5.392348e-07
# 3   3.409264e-07  3.407149e-07  3.444931e-07  3.408869e-07
# 4   3.380569e-07  3.378672e-07  3.399740e-07  3.381990e-07
# 5   3.610545e-07  3.609766e-07  3.638583e-07  3.612107e-07
# 6   5.529187e-07  5.530009e-07  5.855879e-07  5.526038e-07
# 7   8.119448e-06  8.140334e-06  3.223809e-05  8.131900e-06
# 8   8.353252e-07  8.354555e-07  8.463651e-07  8.345140e-07
# 9   3.342576e-07  3.336830e-07  3.404394e-07  3.338723e-07
# 10  7.182088e-07  7.190963e-07  7.356258e-07  7.188505e-07
# 11  6.905494e-07  6.901158e-07  6.993864e-07  6.902811e-07
#
# [12 rows x 79211 columns]

# %% [markdown]
# # Top documentos por topico

# %%
lda_train_results.sort_values('Topic_3', ascending=False)['Topic_3'].head(20)
# Out:
# 557    0.999646
# 67     0.999634
# 556    0.999599
# 185    0.999417
# 428    0.998322
# 817    0.997559
# 473    0.996693
# 708    0.991841
# 487    0.991627
# 679    0.991303
# 360    0.990945
# 355    0.974932
# 531    0.974122
# 876    0.970319
# 401    0.969247
# 404    0.968323
# 160    0.964798
# 864    0.962650
# 380    0.961545
# 517    0.960226
# Name: Topic_3, dtype: float64

# %%
print(lda_train_results.iloc[557])
# Out:
# document_title         Quantitative analysis of large amounts of jour...
# Topic_0                                                         0.000032
# Topic_1                                                         0.000032
# Topic_2                                                         0.000032
# Topic_3                                                         0.999646
# Topic_4                                                         0.000032
# Topic_5                                                         0.000032
# Topic_6                                                         0.000032
# Topic_7                                                         0.000032
# Topic_8                                                         0.000032
# Topic_9                                                         0.000032
# Topic_10                                                        0.000032
# Topic_11                                                        0.000032
# Dominant_Topic                                                   Topic 3
# Perc_Dominant_Topic                                                  1.0
# Name: 557, dtype: object

# %%
print(document_topic_matrix.iloc[557])
# Out:
# 0     0.000032
# 1     0.000032
# 2     0.000032
# 3     0.999646
# 4     0.000032
# 5     0.000032
# 6     0.000032
# 7     0.000032
# 8     0.000032
# 9     0.000032
# 10    0.000032
# 11    0.000032
# Name: 557, dtype: float64

# %%
print(train_data_.document_title.iloc[557])
# Out:
# Quantitative analysis of large amounts of journalistic texts using topic modeling.pdf

# %%
print(train_data_.document_title.iloc[556])
# Out:
# Improving Reading Comprehension in Spanish using iSTART-E - A Pilot Study.pdf

# %%
print(train_data_.document_title.iloc[185])
# Out:
# Motivational profiles related to the academic satisfaction of university students.pdf

# %%
print(train_data_.document_title.iloc[67])
# Out:
# Handbook of Latent Semantic Analysis by Thomas K. Landauer Danielle S. McNamara Simon Dennis Walter Kintsch (z-lib.org).pdf

# %%
print(train_data_.document_title.iloc[817])
# Out:
# The use of equipment-based learning as an active methodology teaching for pharmacology to Nursing students.pdf

# %%
print(train_data_.document_title.iloc[428])
# Out:
# Dynamics of Simultaneous and Imitative Bodily Coordination in Trust and Distrust.pdf

# %%
print(train_data_.document_title.iloc[473])
# Out:
# Evaluating a Tool for Improving Accessibility to Complex Visual Objects.pdf

# %%
print(train_data_.document_title.iloc[708])
# Out:
# Optimizing Semantic Coherence in Topic Models.pdf

# %%
print(train_data_.document_title.iloc[679])
# Out:
# LEXMATH -A tool for the study of available lexicon in mathematics.pdf

# %%
print(train_data_.document_title.iloc[487])
# Out:
# Modelling the loss and retention of contacts in social networks.pdf

# %%
print(train_data_.document_title.iloc[360])
# Out:
# E-learning Training for Spanish Compulsory Secondary Education Teachers to Use SDI as an ICT Educational Resource.pdf

# %% [markdown]
# # SISTEMA RECOMENDACION

# %%
document_topic_matrix
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.000052  0.000052  0.999429  0.000052  0.000052  0.000052  0.000052
# 1    0.000034  0.000034  0.000034  0.000034  0.000034  0.000034  0.763231
# 2    0.586696  0.000065  0.267503  0.000065  0.000065  0.000065  0.007368
# 3    0.000056  0.000056  0.140542  0.000056  0.000056  0.243990  0.489561
# 4    0.000033  0.000033  0.000033  0.000033  0.000033  0.000033  0.186601
# ..        ...       ...       ...       ...       ...       ...       ...
# 964  0.000046  0.000046  0.000046  0.000046  0.000046  0.999491  0.000046
# 965  0.000156  0.000156  0.000156  0.087539  0.000156  0.000156  0.000156
# 966  0.000297  0.000297  0.000297  0.000297  0.000297  0.000297  0.000297
# 967  0.000080  0.000080  0.032414  0.000080  0.000080  0.000080  0.000080
# 968  0.000034  0.000034  0.000034  0.000034  0.000034  0.000034  0.000034
#
#            7         8         9         10        11
# 0    0.000052  0.000052  0.000052  0.000052  0.000052
# 1    0.000034  0.000034  0.009632  0.000034  0.226834
# 2    0.000065  0.021325  0.011862  0.104859  0.000065
# 3    0.125460  0.000056  0.000056  0.000056  0.000056
# 4    0.000033  0.000033  0.671559  0.000033  0.141546
# ..        ...       ...       ...       ...       ...
# 964  0.000046  0.000046  0.000046  0.000046  0.000046
# 965  0.588401  0.000156  0.158603  0.114570  0.049796
# 966  0.000297  0.655663  0.202443  0.000297  0.139224
# 967  0.000080  0.966790  0.000080  0.000080  0.000080
# 968  0.649978  0.000034  0.349508  0.000034  0.000212
#
# [969 rows x 12 columns]

# %%
import extended_similarities as sims
import numpy as np

k = 5

X = np.array(document_topic_matrix)  # pandas to np.array

cos_knn = sims.DistributedCosineKnn(k=k)

indices, distances = cos_knn.fit(input_data=X, n_bucket=10)

# %%
#X[0]

# %%
#indices
doc = 635

print(indices[doc])
#print(distances[doc])
# Out:
# [635 175 741 224 490 135]

# %%
print(doc)
print()
print(lda_train_results.iloc[doc])
print()
document_topic_matrix.iloc[doc]
print(train_data_.document_title.iloc[doc])
print()
print(train_data_.text.iloc[doc][:1000])
# Out:
# 635
#
# document_title         A difference scheme for a degenerating convect...
# Topic_0                                                         0.000036
# Topic_1                                                         0.000036
# Topic_2                                                         0.525984
# Topic_3                                                         0.000036
# Topic_4                                                         0.458059
# Topic_5                                                         0.000036
# Topic_6                                                         0.000036
# Topic_7                                                          0.00025
# Topic_8                                                         0.000036
# Topic_9                                                         0.015418
# Topic_10                                                        0.000036
# Topic_11                                                        0.000036
# Dominant_Topic                                                   Topic 2
# Perc_Dominant_Topic                                                 0.53
# Name: 635, dtype: object
#
# A difference scheme for a degenerating convection-diffusion-reaction system modelling continuous sedimentation.pdf
#
# difference scheme degenerate convection_diffusion_reaction mathematical modelling man sedimentation suspension biofilm granule nitrogen plant raimund burger publications_citations_content_followe camilo mejia november_user_requeste enhancement_downloade difference scheme degenerate convection_diffusion_reaction continuous_sedimentation continuously operate settling_tanks gravity separation solid_liquid suspen sion several industry mathematical form topic ical even space dimension spatially discontinuous_coefficient underlie strongly_degenerate_parabolic nonlinear partial_differential pde extend sedimentation component particle react several soluble component liquid fundamental balance contain mass percentage component solid_liquid_phase reformulate nonlinear pde solve consecutively step explicit scheme scheme combine difference scheme approach percentage propagation component flow main invariant region property imply produce simulation denitrification secondary_settling_tank illustrate

# %%
print(indices[doc][1])
print()
print(lda_train_results.iloc[indices[doc][1]])
print()
print(train_data_.document_title.iloc[indices[doc][1]])
print()
print(train_data_.text.iloc[indices[doc][1]][:1000])
# Out:
# 175
#
# document_title         Structural and Dielectric studies of Mg2+ subs...
# Topic_0                                                         0.000066
# Topic_1                                                         0.000066
# Topic_2                                                         0.627844
# Topic_3                                                         0.000066
# Topic_4                                                         0.342748
# Topic_5                                                         0.000066
# Topic_6                                                         0.000066
# Topic_7                                                         0.000066
# Topic_8                                                         0.000066
# Topic_9                                                         0.028815
# Topic_10                                                        0.000066
# Topic_11                                                        0.000066
# Dominant_Topic                                                   Topic 2
# Perc_Dominant_Topic                                                 0.63
# Name: 175, dtype: object
#
# Structural and Dielectric studies of Mg2+ substituted Ni-Zn ferrite.pdf
#
# structural dielectric substituted_ni_zn_ferrite science citations_reads_author microwave absorbing structure physical spinel compound application adsorbent pigment catalyst bathula varaprasad rajesh_babu_bitra_publication publications_citations_content_followe uploaded bitra december_user_requeste enhancement_downloade science structural dielectric ram prasad physics mvgr humanity chemical formula prepared solid state reaction route step incorporation diamagnetic divalent magnesium expense nickel structural property ferrite propose cation derive theoretical intensity intensity vary concentration magnesium_ion site lattice certain amount calculate observed ray_diffrac_tion intensity agreement site_occupancy divalent establish facilitate magnesium enter site remain e occupy site movement cation magnesium substitution discuss view structural parameter tetrahedral_octahedral cation_cation_cation_anion distance hopping length calculate lattice oxygen parameter structural parameter slight de

# %%
print(indices[doc][2])
print()
print(lda_train_results.iloc[indices[doc][2]])
print()
print(train_data_.document_title.iloc[indices[doc][2]])
print()
print(train_data_.text.iloc[indices[doc][2]][:1000])
# Out:
# 741
#
# document_title         TEM characterization of microstructure evoluti...
# Topic_0                                                         0.059797
# Topic_1                                                          0.00011
# Topic_2                                                         0.576277
# Topic_3                                                          0.00011
# Topic_4                                                         0.331187
# Topic_5                                                          0.00011
# Topic_6                                                          0.00011
# Topic_7                                                          0.00011
# Topic_8                                                         0.031858
# Topic_9                                                          0.00011
# Topic_10                                                         0.00011
# Topic_11                                                         0.00011
# Dominant_Topic                                                   Topic 2
# Perc_Dominant_Topic                                                 0.58
# Name: 741, dtype: object
#
# TEM characterization of microstructure evolution in 12%Cr heat resistant steels.pdf
#
# tem conference citations_reads_authors_including creep resistant intermetallic investigation transformation lave main reinforcement particle coromant gerhard sauthoff max_planck_institute iron anke october_user_requeste tem eisenforschung different carry microscopy stem microstructure correlate mechanical_propertie investigate influence different precipitate creep strength alloy precipitation lave observe several hour creep nucleate exist observe alloy growth coarsening lave slow growth coarsening rate alloy contain lave precipitate well creep property keyword creep resistant steel microstructure_evolution tem lave structural power plant component main steam pipe temperature boiler continuous development creep reflect improvement efficiency power plant steam parameter raise mean increment efficiency equivalent reduction co emission regulation requirement still strong demand efficient power plant goal reach rupture life stress temperature work temperature reduce long creep mechanical_pr

# %%
print(indices[doc][3])
print()
print(lda_train_results.iloc[indices[doc][3]])
print()
print(train_data_.document_title.iloc[indices[doc][3]])
print()
print(train_data_.text.iloc[indices[doc][3]][:1000])
# Out:
# 224
#
# document_title         A Graph-Oriented Model and Query Language for ...
# Topic_0                                                          0.00006
# Topic_1                                                          0.00006
# Topic_2                                                         0.467872
# Topic_3                                                         0.101872
# Topic_4                                                         0.338301
# Topic_5                                                          0.00006
# Topic_6                                                          0.00006
# Topic_7                                                          0.00006
# Topic_8                                                          0.00006
# Topic_9                                                         0.091474
# Topic_10                                                         0.00006
# Topic_11                                                         0.00006
# Dominant_Topic                                                   Topic 2
# Perc_Dominant_Topic                                                 0.47
# Name: 224, dtype: object
#
# A Graph-Oriented Model and Query Language for Events.pdf
#
# graph orient query language event conference andrea_rodriguez_publications_citation content_following_uploade orient query language event chile mromero andrea_udec_cl different application interrelate event sequence event event ing industry work motivate limitation current database query interrelated event propose graph orient query language event extend cur_rent graph incorporate temporal spatial setting event different granularity event representation language implement extensible database event diverse engineer science monitor business knowledge representation active database complementary view event event trigger store query traditional data event active database reactive service event subject data representation query processing event spatio_temporal_database work event spatio_temporal_database event establish happen specific location go event subject lead event entity database entity traditional database relationship event temporal spatial connectivity causality play_important_ro

# %%
print(indices[doc][4])
print()
print(lda_train_results.iloc[indices[doc][4]])
print()
print(train_data_.document_title.iloc[indices[doc][4]])
print()
print(train_data_.text.iloc[indices[doc][4]][:1000])
# Out:
# 490
#
# document_title         A Formal Approach to Qualitative Reasoning on ...
# Topic_0                                                         0.000087
# Topic_1                                                         0.000087
# Topic_2                                                         0.402468
# Topic_3                                                         0.033546
# Topic_4                                                         0.563205
# Topic_5                                                         0.000087
# Topic_6                                                         0.000087
# Topic_7                                                         0.000087
# Topic_8                                                         0.000087
# Topic_9                                                         0.000087
# Topic_10                                                        0.000087
# Topic_11                                                        0.000087
# Dominant_Topic                                                   Topic 4
# Perc_Dominant_Topic                                                 0.56
# Name: 490, dtype: object
#
# A Formal Approach to Qualitative Reasoning on Topological Properties of Networks.pdf
#
# formal approach qualitative_reasone topological property network conference desde link council marroquin publications_citations_content_followe uploaded_andrea_rodriguez june_user_requeste enhancement_downloade formal approach qualitative_reasone topological property network concepci limited relevant distinc tion domain allow flexible way represent reasoning work qualitative rea soning network spatial topological property connectivity topological_invariant describe structural characteristic topologi_cal relationship network network generalize found topological consideration conceptual tool useful different domain social technological network topological property relate concept connectivity different relation overlap important extension power traditional graph network incorporation topological relationship primitve fact recognize spatial domain topological_relation play important role spatial reasoning formal approach subject beneficial several reason malism serve tool identify derive s

# %%
print(indices[doc][5])
print()
print(lda_train_results.iloc[indices[doc][5]])
print()
print(train_data_.document_title.iloc[indices[doc][5]])
print()
print(train_data_.text.iloc[indices[doc][5]][:1000])
# Out:
# 135
#
# document_title         Study of electrical and magnetic properties of...
# Topic_0                                                         0.000093
# Topic_1                                                         0.000093
# Topic_2                                                         0.655492
# Topic_3                                                         0.000093
# Topic_4                                                         0.332159
# Topic_5                                                         0.000093
# Topic_6                                                         0.000093
# Topic_7                                                         0.000093
# Topic_8                                                         0.000093
# Topic_9                                                         0.011516
# Topic_10                                                        0.000093
# Topic_11                                                        0.000093
# Dominant_Topic                                                   Topic 2
# Perc_Dominant_Topic                                                 0.66
# Name: 135, dtype: object
#
# Study of electrical and magnetic properties of Ni – Zn – Mg ferrite system.pdf
#
# discussions_stats_profiles_http electrical_magnetic property modern physics letter microwave absorbing structure physical spinel compound application adsorbent pigment catalyst rajesh_babu_bitra_publication bathula publications_citations_content_followe uploaded bathula varaprasad modern physics letter vol world doi electrical_magnetic property physics woman mvgr polycrystalline step conventional ceramic technique calcination sinter carry air atmosphere respectively natural_cooling_room temperature characterize ray_diffraction_xrd structure determination investigate magnetic electric property saturation_magnetization_curie_temperature initial permeability porosity decreased_drastically quality sinter increment initial permeability series variation observe property discuss light exist understanding keyword temperature initial meability dc_electrical_resistivity ferrite widely_use magnetic core various electromagnetic device responsible technological revolution electrical sistivity magne
