# %%
import os
# define the name of the directory to be created
path = "../Modelo Final"
   
ruta_modelo = path + "/LDA-Model"

# %%
from pycaret.nlp import *

lda_final = load_model(ruta_modelo)
num_topics = len(lda_final.get_topics());

import pandas as pd
import pickle


train_data_dir = path + "/train_data_.sav"
train_tokenized_words_dir = path + "/train_tokenized_words.sav"
train_corpus_dir = path + "/train_corpus.sav"
train_id2word_dir = path + "/train_id2word.sav"


test_data_dir = path + "/test/test_data_.sav"
test_tokenized_words_dir = path + "/test/test_tokenized_words.sav"
test_corpus_dir = path + "/test/test_corpus.sav"
test_id2word_dir = path + "/test/test_id2word.sav"


lda_train_results_dir = path + "/lda_train_results.df"
#lda_test_results_dir = path + "/lda_test_results.df"


train_data_ = pickle.load(open(train_data_dir, 'rb'))
train_tokenized_words = pickle.load(open(train_tokenized_words_dir, 'rb'))                                
train_corpus = pickle.load(open(train_corpus_dir, 'rb'))
train_id2word = pickle.load(open(train_id2word_dir, 'rb')) #Diccionario gensin

test_data_ = pickle.load(open(test_data_dir, 'rb'))
test_tokenized_words = pickle.load(open(test_tokenized_words_dir, 'rb'))                                
test_corpus = pickle.load(open(test_corpus_dir, 'rb'))
test_id2word = pickle.load(open(test_id2word_dir, 'rb')) #Diccionario gensin

lda_train_results = pickle.load(open(lda_train_results_dir, 'rb'))
#lda_test_results = pickle.load(open(lda_test_results_dir, 'rb'))



document_topic_matrix_dir = path + "/document_topic_matrix.sav"
topic_word_matrix_dir = path + "/topic_word_matrix.sav"

document_topic_matrix = pickle.load(open(document_topic_matrix_dir, 'rb'))
topic_word_matrix = pickle.load(open(topic_word_matrix_dir, 'rb'))
# Out:
# Model Sucessfully Loaded

# %%
document_topic_matrix
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.320829  0.000031  0.000031  0.000031  0.000902  0.000031  0.000031
# 1    0.000049  0.000049  0.000049  0.000049  0.000049  0.000049  0.158527
# 2    0.499356  0.000068  0.000068  0.000068  0.000068  0.000068  0.000068
# 3    0.364691  0.072737  0.000248  0.000248  0.000248  0.000248  0.000248
# 4    0.000214  0.000214  0.000214  0.000214  0.000214  0.000214  0.000214
# ..        ...       ...       ...       ...       ...       ...       ...
# 964  0.000240  0.000240  0.000240  0.000240  0.000240  0.000240  0.000240
# 965  0.000019  0.000019  0.000019  0.000019  0.000019  0.834149  0.000019
# 966  0.000043  0.000043  0.000043  0.000043  0.000043  0.000043  0.000043
# 967  0.000049  0.000049  0.000049  0.000049  0.000049  0.705519  0.212711
# 968  0.000178  0.000178  0.000178  0.736101  0.000178  0.085189  0.123082
#
#            7         8         9         10        11        12        13
# 0    0.000031  0.000031  0.000031  0.000031  0.000031  0.677925  0.000031
# 1    0.000049  0.000049  0.000049  0.840886  0.000049  0.000049  0.000049
# 2    0.000068  0.000068  0.000068  0.000068  0.000068  0.000068  0.499830
# 3    0.000248  0.125805  0.000248  0.000248  0.000248  0.434289  0.000248
# 4    0.000214  0.997222  0.000214  0.000214  0.000214  0.000214  0.000214
# ..        ...       ...       ...       ...       ...       ...       ...
# 964  0.000240  0.000240  0.000240  0.038319  0.958800  0.000240  0.000240
# 965  0.000019  0.000019  0.000019  0.000019  0.000019  0.165620  0.000019
# 966  0.000043  0.000043  0.000043  0.000043  0.000043  0.999438  0.000043
# 967  0.000049  0.000049  0.021255  0.060026  0.000049  0.000049  0.000049
# 968  0.000178  0.053846  0.000178  0.000178  0.000178  0.000178  0.000178
#
# [969 rows x 14 columns]

# %%
topic_word_matrix
# Out:
#         abnormal   absence  accessibility  accompany    accord  accumulation  \
# 0   8.000323e-06  0.000266       0.000002   0.000068  0.001532      0.000152
# 1   2.341204e-05  0.000290       0.000002   0.000139  0.002164      0.000003
# 2   1.517502e-05  0.000041       0.000113   0.000020  0.001187      0.000010
# 3   1.732529e-06  0.000387       0.000002   0.000044  0.001503      0.000185
# 4   6.599318e-05  0.000477       0.000128   0.000223  0.000554      0.000090
# 5   1.599243e-05  0.000136       0.000002   0.000062  0.001820      0.000629
# 6   2.450430e-05  0.000216       0.000021   0.000072  0.002055      0.000266
# 7   5.269137e-07  0.000246       0.000508   0.000108  0.001204      0.000033
# 8   5.284270e-05  0.000288       0.000010   0.000041  0.001446      0.000050
# 9   1.780781e-05  0.000040       0.000437   0.000012  0.002522      0.000123
# 10  5.146724e-07  0.000166       0.000033   0.000037  0.001153      0.000041
# 11  5.002318e-06  0.000376       0.000002   0.000033  0.000895      0.000371
# 12  4.237134e-04  0.000706       0.000014   0.000188  0.000602      0.000579
# 13  1.470155e-05  0.000233       0.000002   0.000062  0.001851      0.000039
#
#       accurately   achieve  acquisition       act  ...   pleomorphic  \
# 0   1.115656e-04  0.001173     0.000171  0.000357  ...  4.497640e-07
# 1   5.262460e-05  0.000438     0.000044  0.000201  ...  9.956030e-07
# 2   1.374239e-04  0.000861     0.000207  0.000184  ...  3.223575e-07
# 3   1.498189e-05  0.000334     0.000378  0.000513  ...  7.167180e-07
# 4   1.008606e-04  0.000275     0.000038  0.000420  ...  9.322710e-07
# 5   4.382156e-06  0.000380     0.000166  0.000243  ...  3.953841e-07
# 6   6.834943e-05  0.000416     0.000073  0.000192  ...  4.434721e-07
# 7   1.034791e-05  0.000827     0.000058  0.000270  ...  3.760938e-07
# 8   2.079815e-05  0.000383     0.000064  0.000184  ...  7.603670e-07
# 9   2.131239e-05  0.001284     0.000017  0.000171  ...  1.547205e-06
# 10  6.250132e-05  0.000839     0.000012  0.000177  ...  3.450948e-07
# 11  6.336226e-05  0.000389     0.000021  0.000307  ...  4.787877e-07
# 12  6.007007e-07  0.000308     0.000127  0.000581  ...  3.636408e-07
# 13  8.585396e-05  0.001002     0.000517  0.000131  ...  8.281652e-07
#
#            poach          pudu         pudue           rlt  \
# 0   4.497640e-07  4.497640e-07  4.497640e-07  4.497640e-07
# 1   9.956030e-07  9.956030e-07  9.956030e-07  9.956030e-07
# 2   3.223575e-07  3.223575e-07  3.223575e-07  3.223575e-07
# 3   7.167180e-07  7.170526e-07  7.167180e-07  7.167180e-07
# 4   9.322710e-07  9.322710e-07  9.322710e-07  9.322710e-07
# 5   3.953841e-07  3.953915e-07  3.953841e-07  3.953841e-07
# 6   4.434721e-07  4.434918e-07  4.434721e-07  4.434721e-07
# 7   3.760938e-07  3.760938e-07  3.760938e-07  3.760938e-07
# 8   7.603670e-07  7.604040e-07  7.603670e-07  7.603670e-07
# 9   1.547205e-06  1.547205e-06  1.547205e-06  1.547205e-06
# 10  3.450948e-07  3.450964e-07  3.450948e-07  3.450948e-07
# 11  4.787877e-07  4.787877e-07  4.787877e-07  4.787877e-07
# 12  3.636408e-07  3.636408e-07  3.636408e-07  3.636408e-07
# 13  8.281652e-07  8.281653e-07  8.281652e-07  8.281652e-07
#
#     southern_pudu_pudu_puda  submandibular   suppurative      suscepti  \
# 0              4.497640e-07   4.497640e-07  4.497640e-07  4.497640e-07
# 1              9.956030e-07   9.956030e-07  9.956030e-07  9.956030e-07
# 2              3.223575e-07   3.223575e-07  3.223575e-07  3.223575e-07
# 3              7.167180e-07   7.167180e-07  7.167180e-07  7.167180e-07
# 4              9.322710e-07   9.322710e-07  9.322710e-07  9.322710e-07
# 5              3.953841e-07   3.953841e-07  3.953841e-07  3.953841e-07
# 6              4.434721e-07   4.434721e-07  4.434721e-07  4.434721e-07
# 7              3.760938e-07   3.760938e-07  3.760938e-07  3.760938e-07
# 8              7.603670e-07   7.603670e-07  7.603670e-07  7.603670e-07
# 9              1.547205e-06   1.547205e-06  1.547205e-06  1.547205e-06
# 10             3.450948e-07   3.450948e-07  3.450948e-07  3.450948e-07
# 11             4.787877e-07   4.787877e-07  4.787877e-07  4.787877e-07
# 12             3.636408e-07   3.636408e-07  3.636408e-07  3.636408e-07
# 13             8.281652e-07   8.281652e-07  8.281652e-07  8.281652e-07
#
#     trueperella_pyogene
# 0          4.497640e-07
# 1          9.956030e-07
# 2          3.223575e-07
# 3          7.167180e-07
# 4          9.322710e-07
# 5          3.953841e-07
# 6          4.434721e-07
# 7          3.760938e-07
# 8          7.603670e-07
# 9          1.547205e-06
# 10         3.450948e-07
# 11         4.787877e-07
# 12         3.636408e-07
# 13         8.281652e-07
#
# [14 rows x 80883 columns]

# %% [markdown]
# # Top documentos por topico

# %%
lda_train_results.sort_values('Topic_3', ascending=False)['Topic_3'].head(20)
# Out:
# 145    0.999600
# 545    0.999535
# 663    0.999528
# 479    0.999194
# 492    0.998903
# 290    0.998692
# 457    0.994172
# 928    0.991468
# 840    0.987185
# 475    0.983934
# 44     0.973590
# 656    0.923058
# 800    0.904273
# 860    0.902478
# 236    0.892945
# 343    0.875818
# 436    0.874962
# 838    0.863638
# 328    0.855836
# 10     0.854447
# Name: Topic_3, dtype: float64

# %%
print(lda_train_results.iloc[557])
# Out:
# document_title         Electron Microscopy Characterization Of The Di...
# Topic_0                                                           0.9953
# Topic_1                                                         0.000362
# Topic_2                                                         0.000362
# Topic_3                                                         0.000362
# Topic_4                                                         0.000362
# Topic_5                                                         0.000362
# Topic_6                                                         0.000362
# Topic_7                                                         0.000362
# Topic_8                                                         0.000362
# Topic_9                                                         0.000362
# Topic_10                                                        0.000362
# Topic_11                                                        0.000362
# Topic_12                                                        0.000362
# Topic_13                                                        0.000362
# Dominant_Topic                                                   Topic 0
# Perc_Dominant_Topic                                                  1.0
# Name: 557, dtype: object

# %%
print(document_topic_matrix.iloc[557])
# Out:
# 0     0.995300
# 1     0.000362
# 2     0.000362
# 3     0.000362
# 4     0.000362
# 5     0.000362
# 6     0.000362
# 7     0.000362
# 8     0.000362
# 9     0.000362
# 10    0.000362
# 11    0.000362
# 12    0.000362
# 13    0.000362
# Name: 557, dtype: float64

# %%
print(train_data_.document_title.iloc[557])
# Out:
# Electron Microscopy Characterization Of The Dispersion Strengthened Copper-B 4 C Alloy.pdf

# %%
print(train_data_.document_title.iloc[556])
# Out:
# Cache Performance Study of Portfolio-Based Parallel CDCL SAT Solvers.pdf

# %%
print(train_data_.document_title.iloc[185])
# Out:
# Baseline of Susceptibility to the Cry1F Protein in Mexican Populations of Fall Armyworm.pdf

# %%
print(train_data_.document_title.iloc[67])
# Out:
# What is on the menu Feeding, consumption and cannibalism in exploited stocks of the jumbo squid Dosidicus gigas in south-central Chile.pdf

# %%
print(train_data_.document_title.iloc[817])
# Out:
# Alkaline-catalyzed modification of organosolv lignin Optimization of experimental conditions.pdf

# %%
print(train_data_.document_title.iloc[428])
# Out:
# Association between insulin resistance and the development of cardiovascular disease.pdf

# %%
print(train_data_.document_title.iloc[473])
# Out:
# Sense of Agency in Multi-Step Actions.pdf

# %%
print(train_data_.document_title.iloc[708])
# Out:
# Complex Queries for Moving Object Databases in DHT-Based Systems.pdf

# %%
print(train_data_.document_title.iloc[679])
# Out:
# Canceromics Studies Unravel Tumor’s Glutamine Addiction After Metabolic Reprogramming.pdf

# %%
print(train_data_.document_title.iloc[487])
# Out:
# Green synthesis of hierarchical copper oxide microleaf bundles using Hibiscus cannabinus leaf extract for antibacterial application.pdf

# %%
print(train_data_.document_title.iloc[360])
# Out:
# Macrofauna community patterns in a Chiloe Island channel used intensely for aquaculture the ecological status of its benthic environment.pdf

# %% [markdown]
# # SISTEMA RECOMENDACION

# %%
document_topic_matrix
# Out:
#            0         1         2         3         4         5         6   \
# 0    0.320829  0.000031  0.000031  0.000031  0.000902  0.000031  0.000031
# 1    0.000049  0.000049  0.000049  0.000049  0.000049  0.000049  0.158527
# 2    0.499356  0.000068  0.000068  0.000068  0.000068  0.000068  0.000068
# 3    0.364691  0.072737  0.000248  0.000248  0.000248  0.000248  0.000248
# 4    0.000214  0.000214  0.000214  0.000214  0.000214  0.000214  0.000214
# ..        ...       ...       ...       ...       ...       ...       ...
# 964  0.000240  0.000240  0.000240  0.000240  0.000240  0.000240  0.000240
# 965  0.000019  0.000019  0.000019  0.000019  0.000019  0.834149  0.000019
# 966  0.000043  0.000043  0.000043  0.000043  0.000043  0.000043  0.000043
# 967  0.000049  0.000049  0.000049  0.000049  0.000049  0.705519  0.212711
# 968  0.000178  0.000178  0.000178  0.736101  0.000178  0.085189  0.123082
#
#            7         8         9         10        11        12        13
# 0    0.000031  0.000031  0.000031  0.000031  0.000031  0.677925  0.000031
# 1    0.000049  0.000049  0.000049  0.840886  0.000049  0.000049  0.000049
# 2    0.000068  0.000068  0.000068  0.000068  0.000068  0.000068  0.499830
# 3    0.000248  0.125805  0.000248  0.000248  0.000248  0.434289  0.000248
# 4    0.000214  0.997222  0.000214  0.000214  0.000214  0.000214  0.000214
# ..        ...       ...       ...       ...       ...       ...       ...
# 964  0.000240  0.000240  0.000240  0.038319  0.958800  0.000240  0.000240
# 965  0.000019  0.000019  0.000019  0.000019  0.000019  0.165620  0.000019
# 966  0.000043  0.000043  0.000043  0.000043  0.000043  0.999438  0.000043
# 967  0.000049  0.000049  0.021255  0.060026  0.000049  0.000049  0.000049
# 968  0.000178  0.053846  0.000178  0.000178  0.000178  0.000178  0.000178
#
# [969 rows x 14 columns]

# %%
import extended_similarities as sims
import numpy as np

k = 5

X = np.array(document_topic_matrix)  # pandas to np.array

cos_knn = sims.DistributedCosineKnn(k=k)

indices, distances = cos_knn.fit(input_data=X, n_bucket=10)

# %%
#X[0]

# %%
#indices
doc = 635

print(indices[doc])
#print(distances[doc])
# Out:
# [635 726 124 668  96 962]

# %%
print(doc)
print()
print(lda_train_results.iloc[doc])
print()
document_topic_matrix.iloc[doc]
print(train_data_.document_title.iloc[doc])
print()
print(train_data_.text.iloc[doc][:1000])
# Out:
# 635
#
# document_title         Ideas and perspectives - A strategic assessmen...
# Topic_0                                                         0.227719
# Topic_1                                                          0.00002
# Topic_2                                                          0.00002
# Topic_3                                                         0.006718
# Topic_4                                                          0.00002
# Topic_5                                                         0.000033
# Topic_6                                                          0.04569
# Topic_7                                                         0.116531
# Topic_8                                                          0.00002
# Topic_9                                                          0.00002
# Topic_10                                                         0.00002
# Topic_11                                                        0.603145
# Topic_12                                                         0.00002
# Topic_13                                                         0.00002
# Dominant_Topic                                                  Topic 11
# Perc_Dominant_Topic                                                  0.6
# Name: 635, dtype: object
#
# Ideas and perspectives - A strategic assessment of methane and nitrous oxide measurements in the marine environment.pdf
#
# idea perspective strategic assessment methane_nitrous_oxide environment bonus seam streamline assessment monitor wally publications_citations_content_followe july_user_requeste enhancement_downloade idea perspective strategic assessment methane_nitrous_oxide parv school climate geochemistry california_usa liege center climate earth_planetary space science coastal marine science center atmospheric current address current era rapid accurate climate relevant gas namely production consumption net emission require biome ecosystem susceptible impact change marine environment region act net number climate active trace gas methane_nitrous_oxide temporal spatial control interaction complex biogeochemical physical evaluate quantify importance mechanism relevant marine require combination traditional discipline oceanography microbiology fundamental effort ensure dataset produce independent scientist around_world comparable interoperable equally critical transparent communication community technic

# %%
print(indices[doc][1])
print()
print(lda_train_results.iloc[indices[doc][1]])
print()
print(train_data_.document_title.iloc[indices[doc][1]])
print()
print(train_data_.text.iloc[indices[doc][1]][:1000])
# Out:
# 726
#
# document_title         Bench and Pilot Studies of the Membrane-Aerate...
# Topic_0                                                         0.229729
# Topic_1                                                         0.000056
# Topic_2                                                         0.000056
# Topic_3                                                         0.000056
# Topic_4                                                         0.000056
# Topic_5                                                         0.000056
# Topic_6                                                         0.000056
# Topic_7                                                         0.033109
# Topic_8                                                         0.000056
# Topic_9                                                         0.000056
# Topic_10                                                        0.000056
# Topic_11                                                        0.736547
# Topic_12                                                        0.000056
# Topic_13                                                        0.000056
# Dominant_Topic                                                  Topic 11
# Perc_Dominant_Topic                                                 0.74
# Name: 726, dtype: object
#
# Bench and Pilot Studies of the Membrane-Aerated Biofilm Reactor (MABR) for Energy-Efficient Wastewater Treatment.pdf
#
# bench pilot membrane_aerated_biofilm_reactor pore scale biological degradation modelling scale subsurface ecosystem membrane_aerated_biofilm_reactor publications_citation publications_citations_cristian publications_citations_content_followe efficient_wastewater_treatment air hybrid predict energy cost saving associate air hybrid membrane_biofilm_reactor hybrid_mfbr replace fine bubble diffuser conventional_activated_sludge air supply module evaluate removal combine cod nitrogen hybrid growth biofilm suspend target concentration stringency water reuse scenario reduction power requirement decrease mainly dramatically air flow removal saving treat water predict cost saving highly sensitive cost membrane module electrical power cost sensitive membrane oxidation life suggest hybrid_mbfr provide significant saving energy cost identify key parameter help confirm prediction facilitate scale nerenberg correspond suite biofilm robust reliable effective become indus try extremely energy intensiv

# %%
print(indices[doc][2])
print()
print(lda_train_results.iloc[indices[doc][2]])
print()
print(train_data_.document_title.iloc[indices[doc][2]])
print()
print(train_data_.text.iloc[indices[doc][2]][:1000])
# Out:
# 124
#
# document_title         Energy Efficient Wastewater Treatment via the ...
# Topic_0                                                         0.320849
# Topic_1                                                         0.000298
# Topic_2                                                         0.000298
# Topic_3                                                         0.000298
# Topic_4                                                         0.000298
# Topic_5                                                         0.000298
# Topic_6                                                         0.000298
# Topic_7                                                         0.000298
# Topic_8                                                         0.000298
# Topic_9                                                         0.000298
# Topic_10                                                        0.000298
# Topic_11                                                        0.675573
# Topic_12                                                        0.000298
# Topic_13                                                        0.000298
# Dominant_Topic                                                  Topic 11
# Perc_Dominant_Topic                                                 0.68
# Name: 124, dtype: object
#
# Energy Efficient Wastewater Treatment via the Membrane-Aerated Biofilm Reactor (MABR) Effect of Membrane Fluxes on Performance.pdf
#
# energy efficient_wastewater_treatment membrane_aerated_biofilm_reactor performance boron removal puccinellia frigida publications_citation publications_citations_content_followe march_user_requeste energy efficient_wastewater_treatment performance nerenberg energy identification treatment robust reliable effective become industry standard extremely energy intensive consume electrical power plant energy devote aeration mechanical diffuse air aeration diffuse aeration oxygen supply blower transfer liquid rest evolving bubble supply oxygen transfer liquid blower demand would decrease lead tremendous reduction energy demand methodology hollow_fiber_membrane provide highly efficient mean oxygen transfer supply luman membrane far end membrane seal oxygen passively diffuse membrane wall surround biofilm form membrane outer serve barrier consume oxygen reach bulk_liquid far end fiber seal oxygen delivery bacteria hollow_fiber_membrane make outside diameter small provide specific surface mabr e

# %%
print(indices[doc][3])
print()
print(lda_train_results.iloc[indices[doc][3]])
print()
print(train_data_.document_title.iloc[indices[doc][3]])
print()
print(train_data_.text.iloc[indices[doc][3]][:1000])
# Out:
# 668
#
# document_title         Synthesis and characterization of Gd3+ and Sm3...
# Topic_0                                                         0.277853
# Topic_1                                                         0.000057
# Topic_2                                                         0.000057
# Topic_3                                                         0.000057
# Topic_4                                                         0.000057
# Topic_5                                                         0.000057
# Topic_6                                                         0.000057
# Topic_7                                                         0.000057
# Topic_8                                                         0.000057
# Topic_9                                                         0.000057
# Topic_10                                                        0.000057
# Topic_11                                                         0.65951
# Topic_12                                                        0.000057
# Topic_13                                                        0.062013
# Dominant_Topic                                                  Topic 11
# Perc_Dominant_Topic                                                 0.66
# Name: 668, dtype: object
#
# Synthesis and characterization of Gd3+ and Sm3+ ion doped ceria electrolytes through an in-situ sulphated combustion technique.pdf
#
# gd_sm_ion_dope ceria_electrolyte situ_sulphated_combustion technique citations_reads_authors_including derive carbon aerogel catalyst tar ammonia decomposition semiconductor science publications_citation publications_citations_content_followe uploaded ceramic processing situ_sulphated_combustion technique engineer chile bmaterial niist situ_sulphated_combustion gadolinium samarium ceria_electrolyte solid_oxide fuel cell sofc nitrate gadolinium samarium reactant mix homogenously citric_acid fuel situ addition mixture combust subsequently influence sulphate addition morphology ceria particle analyze situ ion highly favor electrolyte nanometer scale add advantage improve crystallinity tem indicate loosely agglomerate nearly spherically shape maximum combustion sulphate conventionally dope candidate sofc operate temperature oc presently development temperature seriously prove solid intermediate operating temperature operate temperature get reduce ceria dope ion scale ceria inherent fluorit

# %%
print(indices[doc][4])
print()
print(lda_train_results.iloc[indices[doc][4]])
print()
print(train_data_.document_title.iloc[indices[doc][4]])
print()
print(train_data_.text.iloc[indices[doc][4]][:1000])
# Out:
# 96
#
# document_title         Effect of reduced graphene oxide on the struct...
# Topic_0                                                         0.211425
# Topic_1                                                          0.00005
# Topic_2                                                          0.00005
# Topic_3                                                          0.00005
# Topic_4                                                          0.00005
# Topic_5                                                          0.00005
# Topic_6                                                          0.00005
# Topic_7                                                          0.00005
# Topic_8                                                          0.00005
# Topic_9                                                          0.00005
# Topic_10                                                         0.00005
# Topic_11                                                        0.787977
# Topic_12                                                         0.00005
# Topic_13                                                         0.00005
# Dominant_Topic                                                  Topic 11
# Perc_Dominant_Topic                                                 0.79
# Name: 96, dtype: object
#
# Effect of reduced graphene oxide on the structural, optical, adsorption and photocatalytic property of iron oxide nanoparticles.pdf
#
# structural optical adsorption photocatalytic property nanoparticle citations_reads_authors_including residue spectrometry libs infrare phoacoustic spectrometry ftir pas chemometric fondecyt_view_project publications_citations_content_followe enhancement_downloade chemistry new cite new structural optical adsorption photocatalytic property ad jorge ez functionalized feo nanoparticle concentration thermal_decomposition accordance ray_diffraction_xrd fourier_transform infrared_ftir spectroscopy change maghemite observed addition reveal lead distortion nanocuboid rod functionalize rgo act lead quench luminescence behavior rgo surface enhance adsorption acid water achieve adsorption reveal adsorb irradiation hematite_feo stable polymorph ambient nature mechanical thermal_stability visible_light_absorption capability ease receive considerable_attention application serve photocatalyst degradation effluent feo nanoparticle utilize adsorb bivalent heavy_metal_ion water undesirable characteristi

# %%
print(indices[doc][5])
print()
print(lda_train_results.iloc[indices[doc][5]])
print()
print(train_data_.document_title.iloc[indices[doc][5]])
print()
print(train_data_.text.iloc[indices[doc][5]][:1000])
# Out:
# 962
#
# document_title         Magnetically recyclable CoFe 2 O 4 ZnO nanocat...
# Topic_0                                                         0.198313
# Topic_1                                                         0.000054
# Topic_2                                                         0.000054
# Topic_3                                                         0.000054
# Topic_4                                                         0.000054
# Topic_5                                                         0.000054
# Topic_6                                                         0.000054
# Topic_7                                                         0.000054
# Topic_8                                                         0.000054
# Topic_9                                                         0.000054
# Topic_10                                                        0.000054
# Topic_11                                                        0.801045
# Topic_12                                                        0.000054
# Topic_13                                                        0.000054
# Dominant_Topic                                                  Topic 11
# Perc_Dominant_Topic                                                  0.8
# Name: 962, dtype: object
#
# Magnetically recyclable CoFe 2 O 4 ZnO nanocatalysts for the efficient catalytic degradation of Acid Blue 113 under ambient conditions.pdf
#
# magnetically recyclable cofe efficient catalytic_degradation acid blue ambient doi citations_reads_authors_including project belong sequential processing reactor degradable hospital panneerselvam aksum pugazhenthiran_nalenthiran_publications_citation publications_citations_content_followe uploaded panneerselvam enhancement_downloade magnetically recyclable cofeo_zno nanocatalyst efficient catalytic_degradation acid blue ambient krishna cofeo_zno magnetic nanocatalyst synthesize frequency technique enhance optical morphological magnetic catalytic property synthesized_nanocatalyst characterize confirm expected modification nanocatalyst reveal substitutional synthesize tested catalytic_degradation acid know textile pollutant reveal efficient ambient nanocatalyst dosage initial concentration varied fix parameter determine maximum minimum catalyst loading degradation demonstrate fold enhance mineralization compare individual bare nanocatalyst achieve hour magnetic stable consecutive recycle
