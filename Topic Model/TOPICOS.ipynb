# %% [markdown]
# # Topic 0
#
# - vector = `0.017*"water" + 0.006*"flow" + 0.005*"cost" + 0.005*"surface" + 0.005*"period" + 0.005*"production" + 0.004*"temperature" + 0.004*"parameter" + 0.004*"difference" + 0.004*"biofilm" + 0.004*"different" + 0.003*"measure" + 0.003*"simulation" + 0.003*"change" + 0.003*"ball" + 0.003*"state" + 0.003*"decrease" + 0.003*"rate" + 0.003*"observe" + 0.003*"wear" + 0.003*"design" + 0.002*"pressure" + 0.002*"compute" + 0.002*"corrosion" + 0.002*"apply"`
#
# - biofilm bacteriano superficie agua costera , corrocion flujo agua , temperatura, presion
#
#
# # Topic 1
#
# - vector = `0.010*"region" + 0.008*"urban" + 0.007*"development" + 0.006*"regional" + 0.005*"production" + 0.004*"social" + 0.004*"economic" + 0.004*"sector" + 0.004*"city" + 0.004*"higher_education_institution" + 0.004*"local" + 0.004*"chile" + 0.003*"work" + 0.003*"population" + 0.003*"different" + 0.003*"plan" + 0.003*"policy" + 0.003*"support" + 0.003*"project" + 0.003*"national" + 0.003*"country" + 0.003*"provide" + 0.003*"develop" + 0.003*"new" + 0.003*"energy"`
#
# - Desarrollo economico urban ciudad, mediante apoyo a la produccion regional
#
# # Topic 2
#
# - vector = `0.011*"temperature" + 0.007*"reaction" + 0.006*"particle" + 0.005*"gas" + 0.005*"copper" + 0.005*"slag" + 0.005*"different" + 0.004*"surface" + 0.004*"solid" + 0.004*"work" + 0.004*"rate" + 0.004*"form" + 0.004*"spatial" + 0.004*"measure" + 0.004*"concentration" + 0.003*"combustion" + 0.003*"energy" + 0.003*"observe" + 0.003*"metal" + 0.003*"relation" + 0.003*"range" + 0.003*"size" + 0.003*"control" + 0.003*"property" + 0.003*"oxygen"`
#
# - `Copper slag` Estudio sobre 'desecho cobre', obtencion energia reacciones quimicas de estado solido, combustion tempraturas
#
#
# # Topic 3
#
# - vector = `0.009*"word" + 0.008*"topic" + 0.005*"text" + 0.005*"different" + 0.005*"user" + 0.005*"number" + 0.004*"group" + 0.004*"work" + 0.004*"space" + 0.003*"measure" + 0.003*"participant" + 0.003*"structure" + 0.003*"knowledge" + 0.003*"learn" + 0.003*"application" + 0.003*"make" + 0.003*"provide" + 0.003*"represent" + 0.003*"task" + 0.003*"vector" + 0.003*"change" + 0.002*"mean" + 0.002*"social" + 0.002*"new" + 0.002*"lsa"`
#
# - compact data structure Procesamiento de lenguaje natural, modelado de topicos, palabras, texto
#
#
#
# # Topic 4
#
# - vector = `0.007*"user" + 0.006*"number" + 0.005*"point" + 0.005*"different" + 0.004*"instance" + 0.004*"algorithm" + 0.004*"application" + 0.004*"provide" + 0.004*"definition" + 0.004*"describe" + 0.004*"space" + 0.004*"correspond" + 0.004*"approach" + 0.003*"state" + 0.003*"adaptive" + 0.003*"parameter" + 0.003*"propose" + 0.003*"solve" + 0.003*"class" + 0.003*"step" + 0.003*"size" + 0.003*"exist" + 0.003*"apply" + 0.003*"work" + 0.003*"large"`
#
# - solucion algoritmo     intancia   definition structure     user caracterstic          web aplication adaptative feature
#
#
# # Topic 5
#
# - vector = `0.036*"cell" + 0.010*"expression" + 0.009*"protein" + 0.007*"human" + 0.006*"insulin" + 0.005*"control" + 0.004*"reduce" + 0.004*"receptor" + 0.004*"associate" + 0.004*"cancer" + 0.004*"role" + 0.004*"concentration" + 0.004*"suggest" + 0.004*"mediate" + 0.004*"gene" + 0.004*"express" + 0.004*"mouse" + 0.003*"activation" + 0.003*"mechanism" + 0.003*"transport" + 0.003*"glucose" + 0.003*"bind" + 0.003*"compare" + 0.003*"different" + 0.003*"treatment"`
#
# - expreson genes humanos    proteina celula   celula madre  human cancer cell    adult stem cell     cancer stem cell     endotheial cell     tumor cell      insulina
#
# # Topic 6
#
# - vector = `0.009*"strain" + 0.008*"gene" + 0.008*"plant" + 0.007*"isolate" + 0.006*"population" + 0.005*"different" + 0.004*"bacterial" + 0.004*"group" + 0.004*"number" + 0.004*"specie" + 0.004*"region" + 0.004*"genetic" + 0.004*"resistance" + 0.004*"bacteria" + 0.003*"compare" + 0.003*"sequence" + 0.003*"identify" + 0.003*"control" + 0.003*"associate" + 0.003*"water" + 0.003*"observe" + 0.003*"positive" + 0.003*"presence" + 0.003*"soil" + 0.003*"detect"`
#
# - especie planta genes     cepa bacteriana    resistence gene    plant growht     aislar  specie  //  cepa resistente  pylori strain, influenza
#
# # Topic 7
#
# - vector = `0.009*"cell" + 0.008*"growth" + 0.008*"plant" + 0.007*"concentration" + 0.006*"temperature" + 0.006*"strain" + 0.006*"specie" + 0.005*"culture" + 0.005*"different" + 0.005*"production" + 0.004*"protein" + 0.004*"control" + 0.004*"vaccine" + 0.003*"content" + 0.003*"rate" + 0.003*"response" + 0.003*"determine" + 0.003*"grow" + 0.003*"bacterial" + 0.003*"indicate" + 0.003*"produce" + 0.003*"treatment" + 0.003*"respectively" + 0.003*"observe" + 0.003*"lipid"`
#
# -  specie cell plant    growth rate     plant specie  vacuna cultura
#
# # Topic 8
#
# - vector = `0.009*"wood" + 0.007*"pulp" + 0.006*"plant" + 0.006*"different" + 0.006*"treatment" + 0.006*"control" + 0.006*"tree" + 0.005*"content" + 0.005*"specie" + 0.005*"determine" + 0.004*"water" + 0.004*"evaluate" + 0.004*"property" + 0.004*"growth" + 0.004*"cellulose" + 0.003*"fiber" + 0.003*"perform" + 0.003*"concentration" + 0.003*"respectively" + 0.003*"production" + 0.003*"lignin" + 0.003*"yield" + 0.003*"stem" + 0.003*"number" + 0.003*"observe"`
#
# - tratamiento pre germinacion    produccion pulpa madera arbol celulosa fibra agua     eucalyptus specie      water stress    ethanol production
#
# # Topic 9
#
# - vector = `0.009*"water" + 0.007*"site" + 0.006*"specie" + 0.005*"surface" + 0.005*"period" + 0.005*"change" + 0.004*"plant" + 0.004*"observe" + 0.004*"temperature" + 0.004*"different" + 0.004*"depth" + 0.003*"region" + 0.003*"response" + 0.003*"scale" + 0.003*"station" + 0.003*"number" + 0.003*"event" + 0.003*"large" + 0.003*"indicate" + 0.003*"difference" + 0.003*"record" + 0.003*"measure" + 0.003*"mean" + 0.003*"coastal" + 0.003*"parameter"`
#
# - estress hidrido, cambio climatico,  potencial retencion agua de suelos
#
# # Topic 10
#
# - vector = `0.007*"group" + 0.006*"control" + 0.006*"patient" + 0.005*"surface" + 0.005*"implant" + 0.004*"different" + 0.004*"treatment" + 0.004*"risk" + 0.004*"neuron" + 0.004*"compare" + 0.003*"mouse" + 0.003*"change" + 0.003*"cell" + 0.003*"observe" + 0.003*"evaluate" + 0.003*"significant" + 0.003*"treat" + 0.003*"response" + 0.003*"affect" + 0.003*"synaptic" + 0.002*"current" + 0.002*"perform" + 0.002*"positive" + 0.002*"indicate" + 0.002*"population"`
#
# - grupo de control ratones, respuesta implante celulas neuronales
#
#
# # Topic 11
#
# - vector = `0.015*"specie" + 0.014*"forest" + 0.007*"tree" + 0.006*"region" + 0.006*"change" + 0.005*"plant" + 0.005*"restoration" + 0.005*"native" + 0.005*"local" + 0.005*"landscape" + 0.004*"land" + 0.004*"fire" + 0.004*"site" + 0.004*"conservation" + 0.004*"ecosystem" + 0.004*"structure" + 0.004*"community" + 0.004*"management" + 0.004*"different" + 0.004*"pattern" + 0.003*"provide" + 0.003*"ecological" + 0.003*"population" + 0.003*"biodiversity" + 0.003*"global"`
#
# - degradacioon bosque    restauracion ecosistema  conservacion biodiversidad , especia nativa, bosque seco
